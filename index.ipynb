# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in pandas.

# %%
# Replace None with appropriate code

# Import pandas using the standard alias
import pandas as pd

# Load 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv('WorldCupMatches.csv')

# %% [markdown]
# ## Common Methods and Attributes

# %% [markdown]
# Use the correct method to display the **first 7 rows** of the dataset.

# %%
# Your code here
df.head(20)
# Out:
#     Year              Datetime              Stage                  Stadium  \
# 0   1930  13 Jul 1930 - 15:00             Group 1                  Pocitos
# 1   1930  13 Jul 1930 - 15:00             Group 4           Parque Central
# 2   1930  14 Jul 1930 - 12:45             Group 2           Parque Central
# 3   1930  14 Jul 1930 - 14:50             Group 3                  Pocitos
# 4   1930  15 Jul 1930 - 16:00             Group 1           Parque Central
# 5   1930  16 Jul 1930 - 14:45             Group 1           Parque Central
# 6   1930  17 Jul 1930 - 12:45             Group 2           Parque Central
# 7   1930  17 Jul 1930 - 14:45             Group 4           Parque Central
# 8   1930  18 Jul 1930 - 14:30             Group 3       Estadio Centenario
# 9   1930  19 Jul 1930 - 12:50             Group 1       Estadio Centenario
# 10  1930  19 Jul 1930 - 15:00             Group 1       Estadio Centenario
# 11  1930  20 Jul 1930 - 13:00             Group 2       Estadio Centenario
# 12  1930  20 Jul 1930 - 15:00             Group 4       Estadio Centenario
# 13  1930  21 Jul 1930 - 14:50             Group 3       Estadio Centenario
# 14  1930  22 Jul 1930 - 14:45             Group 1       Estadio Centenario
# 15  1930  26 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 16  1930  27 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 17  1930  30 Jul 1930 - 14:15               Final       Estadio Centenario
# 18  1934  27 May 1934 - 16:30   Preliminary round  Stadio Benito Mussolini
# 19  1934  27 May 1934 - 16:30   Preliminary round        Giorgio Ascarelli
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# 0   Montevideo          France                4                1
# 1   Montevideo             USA                3                0
# 2   Montevideo      Yugoslavia                2                1
# 3   Montevideo         Romania                3                1
# 4   Montevideo       Argentina                1                0
# 5   Montevideo           Chile                3                0
# 6   Montevideo      Yugoslavia                4                0
# 7   Montevideo             USA                3                0
# 8   Montevideo         Uruguay                1                0
# 9   Montevideo           Chile                1                0
# 10  Montevideo       Argentina                6                3
# 11  Montevideo          Brazil                4                0
# 12  Montevideo        Paraguay                1                0
# 13  Montevideo         Uruguay                4                0
# 14  Montevideo       Argentina                3                1
# 15  Montevideo       Argentina                6                1
# 16  Montevideo         Uruguay                6                1
# 17  Montevideo         Uruguay                4                2
# 18       Turin         Austria                3                2
# 19      Naples         Hungary                4                2
#
#    Away Team Name                 Win conditions  Attendance  \
# 0          Mexico                                     4444.0
# 1         Belgium                                    18346.0
# 2          Brazil                                    24059.0
# 3            Peru                                     2549.0
# 4          France                                    23409.0
# 5          Mexico                                     9249.0
# 6         Bolivia                                    18306.0
# 7        Paraguay                                    18306.0
# 8            Peru                                    57735.0
# 9          France                                     2000.0
# 10         Mexico                                    42100.0
# 11        Bolivia                                    25466.0
# 12        Belgium                                    12000.0
# 13        Romania                                    70022.0
# 14          Chile                                    41459.0
# 15            USA                                    72886.0
# 16     Yugoslavia                                    79867.0
# 17      Argentina                                    68346.0
# 18         France  Austria win after extra time      16000.0
# 19          Egypt                                     9000.0
#
#     Half-time Home Goals  Half-time Away Goals                     Referee  \
# 0                      3                     0      LOMBARDI Domingo (URU)
# 1                      2                     0           MACIAS Jose (ARG)
# 2                      2                     0         TEJADA Anibal (URU)
# 3                      1                     0       WARNKEN Alberto (CHI)
# 4                      0                     0         REGO Gilberto (BRA)
# 5                      1                     0       CRISTOPHE Henry (BEL)
# 6                      0                     0    MATEUCCI Francisco (URU)
# 7                      2                     0           MACIAS Jose (ARG)
# 8                      0                     0         LANGENUS Jean (BEL)
# 9                      0                     0         TEJADA Anibal (URU)
# 10                     3                     1        SAUCEDO Ulises (BOL)
# 11                     1                     0         BALWAY Thomas (FRA)
# 12                     1                     0     VALLARINO Ricardo (URU)
# 13                     4                     0         REGO Gilberto (BRA)
# 14                     2                     1         LANGENUS Jean (BEL)
# 15                     1                     0         LANGENUS Jean (BEL)
# 16                     3                     1         REGO Gilberto (BRA)
# 17                     1                     2         LANGENUS Jean (BEL)
# 18                     0                     0  VAN MOORSEL Johannes (NED)
# 19                     2                     2    BARLASSINA Rinaldo (ITA)
#
#                  Assistant 1                 Assistant 2  RoundID  MatchID  \
# 0      CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)      201     1096
# 1   MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)      201     1090
# 2    VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)      201     1093
# 3        LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)      201     1098
# 4       SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)      201     1085
# 5    APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)      201     1095
# 6     LOMBARDI Domingo (URU)       WARNKEN Alberto (CHI)      201     1092
# 7    APHESTEGUY Martin (URU)         TEJADA Anibal (URU)      201     1097
# 8        BALWAY Thomas (FRA)       CRISTOPHE Henry (BEL)      201     1099
# 9     LOMBARDI Domingo (URU)         REGO Gilberto (BRA)      201     1094
# 10    ALONSO Gualberto (URU)  RADULESCU Constantin (ROU)      201     1086
# 11  MATEUCCI Francisco (URU)        VALLEJO Gaspar (MEX)      201     1091
# 12         MACIAS Jose (ARG)      LOMBARDI Domingo (URU)      201     1089
# 13     WARNKEN Alberto (CHI)        SAUCEDO Ulises (BOL)      201     1100
# 14     CRISTOPHE Henry (BEL)        SAUCEDO Ulises (BOL)      201     1084
# 15      VALLEJO Gaspar (MEX)       WARNKEN Alberto (CHI)      202     1088
# 16      SAUCEDO Ulises (BOL)         BALWAY Thomas (FRA)      202     1101
# 17      SAUCEDO Ulises (BOL)       CRISTOPHE Henry (BEL)      405     1087
# 18     CAIRONI Camillo (ITA)           BAERT Louis (BEL)      204     1104
# 19    DATTILO Generoso (ITA)          SASSI Otello (ITA)      204     1119
#
#    Home Team Initials Away Team Initials
# 0                 FRA                MEX
# 1                 USA                BEL
# 2                 YUG                BRA
# 3                 ROU                PER
# 4                 ARG                FRA
# 5                 CHI                MEX
# 6                 YUG                BOL
# 7                 USA                PAR
# 8                 URU                PER
# 9                 CHI                FRA
# 10                ARG                MEX
# 11                BRA                BOL
# 12                PAR                BEL
# 13                URU                ROU
# 14                ARG                CHI
# 15                ARG                USA
# 16                URU                YUG
# 17                URU                ARG
# 18                AUT                FRA
# 19                HUN                EGY

# %% [markdown]
# Display the **last 3 rows** of the dataset.

# %%
# Your code here
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    int64
#  17  MatchID               852 non-null    int64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.3+ KB

# %% [markdown]
# Obtain a tuple representing the **number of rows and number of columns**.

# %%
# Your code here
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the **column names**.

# %%
# Your code here
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting DataFrame Information

# %% [markdown]
# When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. **select rows 3 through 5 inclusive**).

# %%
# Your code here
df[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, display the info from **game 5-9** (inclusive), but **only the `"Home Team Name"` and the `"Away Team Name"` columns**.

# %%
# Your code here
subset_df = df.iloc[4:9]

result_df = subset_df[['Home Team Name', 'Away Team Name']]

# %% [markdown]
# Next, we'd like the information on all the games played in **Group 3** for the **1950** World Cup.

# %% [markdown]
# Hint: You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
filtered_df = df[(df['Year'] == 1950) & (df['Stage'] == 'Group 3')]

# %% [markdown]
# Let's repeat the command above, but this time display **only the attendance column** for the Group 3 games.

# %%
# Your code here
attendance_df = df['Attendance']
attendance_df
# Out:
# 0       4444.0
# 1      18346.0
# 2      24059.0
# 3       2549.0
# 4      23409.0
#         ...
# 847    51179.0
# 848    58141.0
# 849    63267.0
# 850    68034.0
# 851    74738.0
# Name: Attendance, Length: 852, dtype: float64

# %% [markdown]
# Throughout the entire history of the World Cup as recorded in this dataset, **how many home games were played by the Netherlands**?
#
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# Your code here
netherlands_home_games = df[df['Home Team Name'] == 'Netherlands']

# Count the number of home games
num_home_games = netherlands_home_games.shape[0]
num_home_games
# Out:
# 32

# %% [markdown]
# **How many games were played by the Netherlands in total**?

# %%
# Your code here
netherlands_total_games = df[(df['Home Team Name'] == 'Netherlands') | (df['Away Team Name'] == 'Netherlands')]
netherlands_total_games.shape[0]
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out **how many games the USA played in the 2014 World Cup**.

# %%
# Your code here
USA_Total_games = df[(df['Home Team Name'] == 'USA') | (df['Away Team Name'] == 'USA')]
USA_Total_games
# Out:
#      Year               Datetime              Stage  \
# 1    1930   13 Jul 1930 - 15:00             Group 4
# 7    1930   17 Jul 1930 - 14:45             Group 4
# 15   1930   26 Jul 1930 - 14:45         Semi-finals
# 24   1934   27 May 1934 - 16:30   Preliminary round
# 55   1950   25 Jun 1950 - 15:00             Group 2
# 62   1950   29 Jun 1950 - 15:00             Group 2
# 68   1950   02 Jul 1950 - 15:00             Group 2
# 416  1990   10 Jun 1990 - 17:00             Group A
# 427  1990   14 Jun 1990 - 21:00             Group A
# 441  1990   19 Jun 1990 - 21:00             Group A
# 466  1994   18 Jun 1994 - 11:30             Group A
# 478  1994   22 Jun 1994 - 19:30             Group A
# 488  1994   26 Jun 1994 - 16:00             Group A
# 505  1994   04 Jul 1994 - 12:30         Round of 16
# 531  1998   15 Jun 1998 - 21:00             Group F
# 545  1998   21 Jun 1998 - 21:00             Group F
# 559  1998   25 Jun 1998 - 21:00             Group F
# 595  2002   05 Jun 2002 - 18:00             Group D
# 609  2002   10 Jun 2002 - 15:30             Group D
# 626  2002   14 Jun 2002 - 20:30             Group D
# 633  2002  17 June 2002 - 15:30         Round of 16
# 637  2002   21 Jun 2002 - 20:30      Quarter-finals
# 653  2006   12 Jun 2006 - 18:00             Group E
# 669  2006   17 Jun 2006 - 21:00             Group E
# 685  2006   22 Jun 2006 - 16:00             Group E
# 712  2010   12 Jun 2010 - 20:30             Group C
# 729  2010   18 Jun 2010 - 16:00             Group C
# 745  2010   23 Jun 2010 - 16:00             Group C
# 757  2010   26 Jun 2010 - 20:30         Round of 16
# 785  2014   16 Jun 2014 - 19:00             Group G
# 803  2014   22 Jun 2014 - 18:00             Group G
# 816  2014   26 Jun 2014 - 13:00             Group G
# 835  2014   01 Jul 2014 - 17:00         Round of 16
# 843  2014   01 Jul 2014 - 17:00         Round of 16
#
#                                    Stadium               City  Home Team Name  \
# 1                           Parque Central        Montevideo              USA
# 7                           Parque Central        Montevideo              USA
# 15                      Estadio Centenario        Montevideo        Argentina
# 24                           Nazionale PNF              Rome            Italy
# 55                        Durival de Brito          Curitiba            Spain
# 62                           Independencia    Belo Horizonte              USA
# 68                          Ilha do Retiro            Recife            Chile
# 416                               Comunale          Florence              USA
# 427                        Stadio Olimpico              Rome            Italy
# 441                               Comunale          Florence          Austria
# 466                     Pontiac Silverdome           Detroit              USA
# 478                              Rose Bowl       Los Angeles              USA
# 488                              Rose Bowl       Los Angeles              USA
# 505                       Stanford Stadium     San Francisco           Brazil
# 531                       Parc des Princes             Paris          Germany
# 545                       Stade de Gerland              Lyon              USA
# 559                           La Beaujoire            Nantes              USA
# 595                Suwon World Cup Stadium             Suwon              USA
# 609                Daegu World Cup Stadium             Daegu   Korea Republic
# 626              Daejeon World Cup Stadium           Daejeon           Poland
# 633               Jeonju World Cup Stadium            Jeonju           Mexico
# 637                 Munsu Football Stadium             Ulsan          Germany
# 653  FIFA World Cup Stadium, Gelsenkirchen     Gelsenkirchen              USA
# 669                   Fritz-Walter-Stadion    Kaiserslautern            Italy
# 685                        Franken-Stadion         Nuremberg            Ghana
# 712           Royal Bafokeng Sports Palace           Phokeng          England
# 729                     Ellis Park Stadium      Johannesburg         Slovenia
# 745                Loftus Versfeld Stadium  Tshwane/Pretoria              USA
# 757           Royal Bafokeng Sports Palace           Phokeng              USA
# 785                      Estadio das Dunas             Natal            Ghana
# 803                         Arena Amazonia            Manaus              USA
# 816                       Arena Pernambuco            Recife              USA
# 835                       Arena Fonte Nova          Salvador          Belgium
# 843                       Arena Fonte Nova          Salvador          Belgium
#
#      Home Team Goals  Away Team Goals  Away Team Name  \
# 1                  3                0         Belgium
# 7                  3                0        Paraguay
# 15                 6                1             USA
# 24                 7                1             USA
# 55                 3                1             USA
# 62                 1                0         England
# 68                 5                2             USA
# 416                1                5  Czechoslovakia
# 427                1                0             USA
# 441                2                1             USA
# 466                1                1     Switzerland
# 478                2                1        Colombia
# 488                0                1         Romania
# 505                1                0             USA
# 531                2                0             USA
# 545                1                2            Iran
# 559                0                1      Yugoslavia
# 595                3                2        Portugal
# 609                1                1             USA
# 626                3                1             USA
# 633                0                2             USA
# 637                1                0             USA
# 653                0                3  Czech Republic
# 669                1                1             USA
# 685                2                1             USA
# 712                1                1             USA
# 729                2                2             USA
# 745                1                0         Algeria
# 757                1                2           Ghana
# 785                1                2             USA
# 803                2                2        Portugal
# 816                0                1         Germany
# 835                2                1             USA
# 843                2                1             USA
#
#                     Win conditions  Attendance  Half-time Home Goals  \
# 1                                      18346.0                     2
# 7                                      18306.0                     2
# 15                                     72886.0                     1
# 24                                     25000.0                     3
# 55                                      9511.0                     0
# 62                                     10151.0                     1
# 68                                      8501.0                     2
# 416                                    33266.0                     0
# 427                                    73423.0                     1
# 441                                    34857.0                     0
# 466                                    73425.0                     1
# 478                                    93869.0                     1
# 488                                    93869.0                     0
# 505                                    84147.0                     0
# 531                                    45500.0                     1
# 545                                    39100.0                     0
# 559                                    35500.0                     0
# 595                                    37306.0                     3
# 609                                    60778.0                     0
# 626                                    26482.0                     2
# 633                                    36380.0                     0
# 637                                    37337.0                     1
# 653                                    52000.0                     0
# 669                                    46000.0                     1
# 685                                    41000.0                     2
# 712                                    38646.0                     1
# 729                                    45573.0                     2
# 745                                    35827.0                     0
# 757    Ghana win after extra time      34976.0                     0
# 785                                    39760.0                     0
# 803                                    40123.0                     0
# 816                                    41876.0                     0
# 835  Belgium win after extra time      51227.0                     0
# 843  Belgium win after extra time      51227.0                     0
#
#      Half-time Away Goals                         Referee  \
# 1                       0               MACIAS Jose (ARG)
# 7                       0               MACIAS Jose (ARG)
# 15                      0             LANGENUS Jean (BEL)
# 24                      0               MERCET Rene (SUI)
# 55                      1               VIANA Mario (BRA)
# 62                      0          DATTILO Generoso (ITA)
# 68                      0            GARDELLI Mario (BRA)
# 416                     2       ROETHLISBERGER Kurt (SUI)
# 427                     0    CODESAL MENDEZ Edgardo (MEX)
# 441                     0           AL SHARIF Jamal (SYR)
# 466                     1  LAMOLINA Francisco Oscar (ARG)
# 478                     0              BALDAS Fabio (ITA)
# 488                     1        VAN DER ENDE Mario (NED)
# 505                     0              QUINIOU Joel (FRA)
# 531                     0              BELQOLA Said (MAR)
# 545                     1                 MEIER Urs (SUI)
# 559                     1         EL GHANDOUR Gamal (EGY)
# 595                     1              MORENO Byron (ECU)
# 609                     1                 MEIER Urs (SUI)
# 626                     0                    LU Jun (CHN)
# 633                     1        MELO PEREIRA Vitor (POR)
# 637                     0               DALLAS Hugh (SCO)
# 653                     2           AMARILLA Carlos (PAR)
# 669                     1           LARRIONDA Jorge (URU)
# 685                     1               MERK Markus (GER)
# 712                     1              SIMON Carlos (BRA)
# 729                     0           Koman COULIBALY (MLI)
# 745                     0        DE BLEECKERE Frank (BEL)
# 757                     0             KASSAI Viktor (HUN)
# 785                     1            ERIKSSON Jonas (SWE)
# 803                     1             PITANA Nestor (ARG)
# 816                     0           Ravshan IRMATOV (UZB)
# 835                     0           HAIMOUDI Djamel (ALG)
# 843                     0           HAIMOUDI Djamel (ALG)
#
#                               Assistant 1                     Assistant 2  \
# 1                MATEUCCI Francisco (URU)           WARNKEN Alberto (CHI)
# 7                 APHESTEGUY Martin (URU)             TEJADA Anibal (URU)
# 15                   VALLEJO Gaspar (MEX)           WARNKEN Alberto (CHI)
# 24                   ESCARTIN Pedro (ESP)           ZENISEK Bohumil (TCH)
# 55             DA COSTA VIEIRA Jose (POR)       DE LA SALLE Charles (FRA)
# 62              DE LA SALLE Charles (FRA)          GALEATI Giovanni (ITA)
# 68                HEYEN Mario Ruben (PAR)           ALVAREZ Alfredo (BOL)
# 416           VAN LANGENHOVE Marcel (BEL)          SCHMIDHUBER Aron (GER)
# 427  CARDELLINO DE SAN VICENTE Juan (URU)        ULLOA MORERA Berny (CRC)
# 441                  LORENC Richard (AUS)            PETROVIC Zoran (SRB)
# 466                   TAIBI Ernesto (ARG)           ZARATE Venancio (PAR)
# 478               RAMICONE Domenico (ITA)  RHARIB El Jilali Mohamed (MAR)
# 488                     DOLSTRA Jan (NED)            DUNSTER Gordon (AUS)
# 505                   PARK Hae-Yong (KOR)           EVERSTIG Mikael (SWE)
# 531                  MANSRI Mohamed (TUN)            NILSSON Mikael (SWE)
# 545                  RAUSIS Laurent (SUI)        GRIGORESCU Nicolae (ROU)
# 559                    SALIE Achmat (RSA)               WARREN Mark (ENG)
# 595                    FIERRO Bomer (ECU)            HASSOUNEH Awni (JOR)
# 609                   BEREUTER Egon (AUT)             TOMUSANGE Ali (UGA)
# 626                    FIERRO Bomer (ECU)                 POOL Jaap (NED)
# 633                    MATOS Carlos (POR)             BEREUTER Egon (AUT)
# 637                    SHARP Philip (ENG)              ALTRAIFI Ali (KSA)
# 653                   ANDINO Amelio (PAR)             BERNAL Manuel (PAR)
# 669                     RIAL Walter (URU)             FANDINO Pablo (URU)
# 685               SCHRAER Christian (GER)        SALVER Jan-Hendrik (GER)
# 712                HAUSMANN Altemir (BRA)            BRAATZ Roberto (BRA)
# 729                  ACHIK Redouane (MAR)     MANUEL CANDIDO Inacio (ANG)
# 745                   HERMANS Peter (BEL)            VROMANS Walter (BEL)
# 757                      EROS Gabor (HUN)               VAMOS Tibor (HUN)
# 785               KLASENIUS Mathias (SWE)           WARNMARK Daniel (SWE)
# 803                  MAIDANA Hernan (ARG)        BELATTI Juan Pablo (ARG)
# 816           RASULOV Abduxamidullo (UZB)        KOCHKAROV Bakhadyr (KGZ)
# 835                  ACHIK Redouane (MAR)         ETCHIALI Abdelhak (ALG)
# 843                  ACHIK Redouane (MAR)         ETCHIALI Abdelhak (ALG)
#
#       RoundID    MatchID Home Team Initials Away Team Initials
# 1         201       1090                USA                BEL
# 7         201       1097                USA                PAR
# 15        202       1088                ARG                USA
# 24        204       1135                ITA                USA
# 55        208       1208                ESP                USA
# 62        208       1202                USA                ENG
# 68        208       1194                CHI                USA
# 416       322        355                USA                TCH
# 427       322        265                ITA                USA
# 441       322         48                AUT                USA
# 466       337       3051                USA                SUI
# 478       337       3063                USA                COL
# 488       337       3073                USA                ROU
# 505       338       3090                BRA                USA
# 531      1014       8738                GER                USA
# 545      1014       8754                USA                IRN
# 559      1014       8768                USA                YUG
# 595  43950100   43950016                USA                POR
# 609  43950100   43950030                KOR                USA
# 626  43950100   43950048                POL                USA
# 633  43950200   43950053                MEX                USA
# 637  43950300   43950058                GER                USA
# 653  97410100   97410010                USA                CZE
# 669  97410100   97410025                ITA                USA
# 685  97410100   97410042                GHA                USA
# 712    249722  300061466                ENG                USA
# 729    249722  300061463                SVN                USA
# 745    249722  300061461                USA                ALG
# 757    249717  300061503                USA                GHA
# 785    255931  300186512                GHA                USA
# 803    255931  300186483                USA                POR
# 816    255931  300186469                USA                GER
# 835    255951  300186497                BEL                USA
# 843    255951  300186497                BEL                USA

# %% [markdown]
# Now, let's try to find out **how many countries participated in the 1986 World Cup**.

# %% [markdown]
# Hint 1: As a first step, create a new dataset that only contains games in that year.
#
# Hint 2: Make sure you don't end up with duplicate country names. Consider using `set()` or `.unique()`.

# %%
# Your code here
df_worldcupgames_year = df[(df['Year'] == 1986)]
df_worldcupgames_year

# Extract unique country names from both "Home Team Name" and "Away Team Name" columns
home_teams = df_worldcupgames_year['Home Team Name'].unique()
away_teams = df_worldcupgames_year['Away Team Name'].unique()

# %% [markdown]
# ## Changing Values and Creating New Columns

# %% [markdown]
# In World Cup history, **how many matches had 5 goals or more in total**? Create a column `"Total Goals"` to answer this question.

# %%
# Your code here
df['Total Goals'] = df['Home Team Goals'] + df['Away Team Goals']

# Filter the DataFrame for matches with 5 or more total goals
high_scoring_matches = df[df['Total Goals'] >= 5]

high_scoring_matches
# Out:
#      Year              Datetime        Stage             Stadium  \
# 0    1930  13 Jul 1930 - 15:00       Group 1             Pocitos
# 10   1930  19 Jul 1930 - 15:00       Group 1  Estadio Centenario
# 15   1930  26 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 16   1930  27 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 17   1930  30 Jul 1930 - 14:15         Final  Estadio Centenario
# ..    ...                   ...          ...                 ...
# 806  2014  23 Jun 2014 - 17:00       Group A    Estadio Nacional
# 810  2014  24 Jun 2014 - 16:00       Group C      Arena Pantanal
# 812  2014  25 Jun 2014 - 13:00       Group F   Estadio Beira-Rio
# 826  2014  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
# 848  2014  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# 0        Montevideo          France                4                1
# 10       Montevideo       Argentina                6                3
# 15       Montevideo       Argentina                6                1
# 16       Montevideo         Uruguay                6                1
# 17       Montevideo         Uruguay                4                2
# ..               ...            ...              ...              ...
# 806        Brasilia        Cameroon                1                4
# 810          Cuiaba           Japan                1                4
# 812    Porto Alegre         Nigeria                2                3
# 826  Belo Horizonte          Brazil                1                7
# 848  Belo Horizonte          Brazil                1                7
#
#     Away Team Name Win conditions  ...  Half-time Home Goals  \
# 0           Mexico                 ...                     3
# 10          Mexico                 ...                     3
# 15             USA                 ...                     1
# 16      Yugoslavia                 ...                     3
# 17       Argentina                 ...                     1
# ..             ...            ...  ...                   ...
# 806         Brazil                 ...                     1
# 810       Colombia                 ...                     1
# 812      Argentina                 ...                     1
# 826        Germany                 ...                     0
# 848        Germany                 ...                     0
#
#      Half-time Away Goals                 Referee              Assistant 1  \
# 0                       0  LOMBARDI Domingo (URU)    CRISTOPHE Henry (BEL)
# 10                      1    SAUCEDO Ulises (BOL)   ALONSO Gualberto (URU)
# 15                      0     LANGENUS Jean (BEL)     VALLEJO Gaspar (MEX)
# 16                      1     REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)
# 17                      2     LANGENUS Jean (BEL)     SAUCEDO Ulises (BOL)
# ..                    ...                     ...                      ...
# 806                     2    ERIKSSON Jonas (SWE)  KLASENIUS Mathias (SWE)
# 810                     1     PROENCA Pedro (POR)    MIRANDA Bertino (POR)
# 812                     2    Nicola RIZZOLI (ITA)    Renato FAVERANI (ITA)
# 826                     5   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
# 848                     5   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
#
#                     Assistant 2 RoundID    MatchID  Home Team Initials  \
# 0           REGO Gilberto (BRA)     201       1096                 FRA
# 10   RADULESCU Constantin (ROU)     201       1086                 ARG
# 15        WARNKEN Alberto (CHI)     202       1088                 ARG
# 16          BALWAY Thomas (FRA)     202       1101                 URU
# 17        CRISTOPHE Henry (BEL)     405       1087                 URU
# ..                          ...     ...        ...                 ...
# 806       WARNMARK Daniel (SWE)  255931  300186472                 CMR
# 810            TRIGO Jose (POR)  255931  300186457                 JPN
# 812        Andrea STEFANI (ITA)  255931  300186458                 NGA
# 826       QUINTERO Marcos (MEX)  255955  300186474                 BRA
# 848       QUINTERO Marcos (MEX)  255955  300186474                 BRA
#
#     Away Team Initials Total Goals
# 0                  MEX           5
# 10                 MEX           9
# 15                 USA           7
# 16                 YUG           7
# 17                 ARG           6
# ..                 ...         ...
# 806                BRA           5
# 810                COL           5
# 812                ARG           5
# 826                GER           8
# 848                GER           8
#
# [147 rows x 21 columns]

# %% [markdown]
# Now **create a new column `"Half-time Goals"`** in `df` that includes both home and away values.

# %%
# Your code here
df['Half-time Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']
df
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# 2         Parque Central      Montevideo      Yugoslavia                2
# 3                Pocitos      Montevideo         Romania                3
# 4         Parque Central      Montevideo       Argentina                1
# ..                   ...              ...            ...              ...
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 0                  1         Mexico
# 1                  0        Belgium
# 2                  1         Brazil
# 3                  1           Peru
# 4                  0         France
# ..               ...            ...                                    ...
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      ...  Half-time Away Goals                 Referee  \
# 0    ...                     0  LOMBARDI Domingo (URU)
# 1    ...                     0       MACIAS Jose (ARG)
# 2    ...                     0     TEJADA Anibal (URU)
# 3    ...                     0   WARNKEN Alberto (CHI)
# 4    ...                     0     REGO Gilberto (BRA)
# ..   ...                   ...                     ...
# 847  ...                     0   Ravshan IRMATOV (UZB)
# 848  ...                     5   RODRIGUEZ Marco (MEX)
# 849  ...                     0      C�neyt �AKIR (TUR)
# 850  ...                     2   HAIMOUDI Djamel (ALG)
# 851  ...                     0    Nicola RIZZOLI (ITA)
#
#                      Assistant 1                 Assistant 2 RoundID  \
# 0          CRISTOPHE Henry (BEL)         REGO Gilberto (BRA)     201
# 1       MATEUCCI Francisco (URU)       WARNKEN Alberto (CHI)     201
# 2        VALLARINO Ricardo (URU)         BALWAY Thomas (FRA)     201
# 3            LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)     201
# 4           SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)     201
# ..                           ...                         ...     ...
# 847  RASULOV Abduxamidullo (UZB)    KOCHKAROV Bakhadyr (KGZ)  255953
# 848      TORRENTERA Marvin (MEX)       QUINTERO Marcos (MEX)  255955
# 849         DURAN Bahattin (TUR)           ONGUN Tarik (TUR)  255955
# 850         ACHIK Redouane (MAR)     ETCHIALI Abdelhak (ALG)  255957
# 851        Renato FAVERANI (ITA)        Andrea STEFANI (ITA)  255959
#
#        MatchID  Home Team Initials  Away Team Initials Total Goals  \
# 0         1096                 FRA                 MEX           5
# 1         1090                 USA                 BEL           3
# 2         1093                 YUG                 BRA           3
# 3         1098                 ROU                 PER           4
# 4         1085                 ARG                 FRA           1
# ..         ...                 ...                 ...         ...
# 847  300186488                 NED                 CRC           0
# 848  300186474                 BRA                 GER           8
# 849  300186490                 NED                 ARG           0
# 850  300186502                 BRA                 NED           3
# 851  300186501                 GER                 ARG           1
#
#     Half-time Goals
# 0                 3
# 1                 2
# 2                 2
# 3                 1
# 4                 0
# ..              ...
# 847               0
# 848               5
# 849               0
# 850               2
# 851               0
#
# [852 rows x 22 columns]

# %%
# Run this cell without changes to see your new column
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Total Goals', 'Half-time Goals'],
#       dtype='object')

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Run this cell without changes

# Display all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns 
df['Home Team Name'] = df['Home Team Name'].replace(['South Korea', 'North Korea'], 'Korea')
df['Away Team Name'] = df['Away Team Name'].replace(['South Korea', 'North Korea'], 'Korea')

# Replace "Home Team Initials" and "Away Team Initials" entries "KOR" and "PRK" with "NSK"
df['Home Team Initials'] = df['Home Team Initials'].replace(['KOR', 'PRK'], 'NSK')
df['Away Team Initials'] = df['Away Team Initials'].replace(['KOR', 'PRK'], 'NSK')

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
df.tail(50)
# Out:
#      Year              Datetime                     Stage  \
# 802  2014  22 Jun 2014 - 16:00                    Group H
# 803  2014  22 Jun 2014 - 18:00                    Group G
# 804  2014  23 Jun 2014 - 13:00                    Group B
# 805  2014  23 Jun 2014 - 13:00                    Group B
# 806  2014  23 Jun 2014 - 17:00                    Group A
# 807  2014  23 Jun 2014 - 17:00                    Group A
# 808  2014  24 Jun 2014 - 13:00                    Group D
# 809  2014  24 Jun 2014 - 13:00                    Group D
# 810  2014  24 Jun 2014 - 16:00                    Group C
# 811  2014  24 Jun 2014 - 17:00                    Group C
# 812  2014  25 Jun 2014 - 13:00                    Group F
# 813  2014  25 Jun 2014 - 13:00                    Group F
# 814  2014  25 Jun 2014 - 16:00                    Group E
# 815  2014  25 Jun 2014 - 17:00                    Group E
# 816  2014  26 Jun 2014 - 13:00                    Group G
# 817  2014  26 Jun 2014 - 13:00                    Group G
# 818  2014  26 Jun 2014 - 17:00                    Group H
# 819  2014  26 Jun 2014 - 17:00                    Group H
# 820  2014  28 Jun 2014 - 13:00                Round of 16
# 821  2014  28 Jun 2014 - 17:00                Round of 16
# 822  2014  30 Jun 2014 - 13:00                Round of 16
# 823  2014  30 Jun 2014 - 17:00                Round of 16
# 824  2014  04 Jul 2014 - 17:00             Quarter-finals
# 825  2014  04 Jul 2014 - 13:00             Quarter-finals
# 826  2014  08 Jul 2014 - 17:00                Semi-finals
# 827  2014  12 Jul 2014 - 17:00   Play-off for third place
# 828  2014  13 Jul 2014 - 16:00                      Final
# 829  2014  09 Jul 2014 - 17:00                Semi-finals
# 830  2014  05 Jul 2014 - 17:00             Quarter-finals
# 831  2014  05 Jul 2014 - 13:00             Quarter-finals
# 832  2014  29 Jun 2014 - 13:00                Round of 16
# 833  2014  29 Jun 2014 - 17:00                Round of 16
# 834  2014  01 Jul 2014 - 13:00                Round of 16
# 835  2014  01 Jul 2014 - 17:00                Round of 16
# 836  2014  28 Jun 2014 - 13:00                Round of 16
# 837  2014  28 Jun 2014 - 17:00                Round of 16
# 838  2014  29 Jun 2014 - 13:00                Round of 16
# 839  2014  29 Jun 2014 - 17:00                Round of 16
# 840  2014  30 Jun 2014 - 13:00                Round of 16
# 841  2014  30 Jun 2014 - 17:00                Round of 16
# 842  2014  01 Jul 2014 - 13:00                Round of 16
# 843  2014  01 Jul 2014 - 17:00                Round of 16
# 844  2014  04 Jul 2014 - 13:00             Quarter-finals
# 845  2014  04 Jul 2014 - 17:00             Quarter-finals
# 846  2014  05 Jul 2014 - 13:00             Quarter-finals
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City              Home Team Name  \
# 802    Estadio Beira-Rio    Porto Alegre               Korea Republic
# 803       Arena Amazonia          Manaus                          USA
# 804     Arena da Baixada        Curitiba                    Australia
# 805   Arena de Sao Paulo       Sao Paulo                  Netherlands
# 806     Estadio Nacional        Brasilia                     Cameroon
# 807     Arena Pernambuco          Recife                      Croatia
# 808    Estadio das Dunas           Natal                        Italy
# 809     Estadio Mineirao  Belo Horizonte                   Costa Rica
# 810       Arena Pantanal          Cuiaba                        Japan
# 811     Estadio Castelao       Fortaleza                       Greece
# 812    Estadio Beira-Rio    Porto Alegre                      Nigeria
# 813     Arena Fonte Nova        Salvador   rn">Bosnia and Herzegovina
# 814       Arena Amazonia          Manaus                     Honduras
# 815  Estadio do Maracana  Rio De Janeiro                      Ecuador
# 816     Arena Pernambuco          Recife                          USA
# 817     Estadio Nacional        Brasilia                     Portugal
# 818   Arena de Sao Paulo       Sao Paulo               Korea Republic
# 819     Arena da Baixada        Curitiba                      Algeria
# 820     Estadio Mineirao  Belo Horizonte                       Brazil
# 821  Estadio do Maracana  Rio De Janeiro                     Colombia
# 822     Estadio Nacional        Brasilia                       France
# 823    Estadio Beira-Rio    Porto Alegre                      Germany
# 824     Estadio Castelao       Fortaleza                       Brazil
# 825  Estadio do Maracana  Rio De Janeiro                       France
# 826     Estadio Mineirao  Belo Horizonte                       Brazil
# 827     Estadio Nacional        Brasilia                       Brazil
# 828  Estadio do Maracana  Rio De Janeiro                      Germany
# 829   Arena de Sao Paulo       Sao Paulo                  Netherlands
# 830     Arena Fonte Nova        Salvador                  Netherlands
# 831     Estadio Nacional        Brasilia                    Argentina
# 832     Estadio Castelao       Fortaleza                  Netherlands
# 833     Arena Pernambuco          Recife                   Costa Rica
# 834   Arena de Sao Paulo       Sao Paulo                    Argentina
# 835     Arena Fonte Nova        Salvador                      Belgium
# 836     Estadio Mineirao  Belo Horizonte                       Brazil
# 837  Estadio do Maracana  Rio De Janeiro                     Colombia
# 838     Estadio Castelao       Fortaleza                  Netherlands
# 839     Arena Pernambuco          Recife                   Costa Rica
# 840     Estadio Nacional        Brasilia                       France
# 841    Estadio Beira-Rio    Porto Alegre                      Germany
# 842   Arena de Sao Paulo       Sao Paulo                    Argentina
# 843     Arena Fonte Nova        Salvador                      Belgium
# 844  Estadio do Maracana  Rio De Janeiro                       France
# 845     Estadio Castelao       Fortaleza                       Brazil
# 846     Estadio Nacional        Brasilia                    Argentina
# 847     Arena Fonte Nova        Salvador                  Netherlands
# 848     Estadio Mineirao  Belo Horizonte                       Brazil
# 849   Arena de Sao Paulo       Sao Paulo                  Netherlands
# 850     Estadio Nacional        Brasilia                       Brazil
# 851  Estadio do Maracana  Rio De Janeiro                      Germany
#
#      Home Team Goals  Away Team Goals Away Team Name  \
# 802                2                4        Algeria
# 803                2                2       Portugal
# 804                0                3          Spain
# 805                2                0          Chile
# 806                1                4         Brazil
# 807                1                3         Mexico
# 808                0                1        Uruguay
# 809                0                0        England
# 810                1                4       Colombia
# 811                2                1  C�te d'Ivoire
# 812                2                3      Argentina
# 813                3                1        IR Iran
# 814                0                3    Switzerland
# 815                0                0         France
# 816                0                1        Germany
# 817                2                1          Ghana
# 818                0                1        Belgium
# 819                1                1         Russia
# 820                1                1          Chile
# 821                2                0        Uruguay
# 822                2                0        Nigeria
# 823                2                1        Algeria
# 824                2                1       Colombia
# 825                0                1        Germany
# 826                1                7        Germany
# 827                0                3    Netherlands
# 828                1                0      Argentina
# 829                0                0      Argentina
# 830                0                0     Costa Rica
# 831                1                0        Belgium
# 832                2                1         Mexico
# 833                1                1         Greece
# 834                1                0    Switzerland
# 835                2                1            USA
# 836                1                1          Chile
# 837                2                0        Uruguay
# 838                2                1         Mexico
# 839                1                1         Greece
# 840                2                0        Nigeria
# 841                2                1        Algeria
# 842                1                0    Switzerland
# 843                2                1            USA
# 844                0                1        Germany
# 845                2                1       Colombia
# 846                1                0        Belgium
# 847                0                0     Costa Rica
# 848                1                7        Germany
# 849                0                0      Argentina
# 850                0                3    Netherlands
# 851                1                0      Argentina
#
#                             Win conditions  ...  Half-time Away Goals  \
# 802                                         ...                     3
# 803                                         ...                     1
# 804                                         ...                     1
# 805                                         ...                     0
# 806                                         ...                     2
# 807                                         ...                     0
# 808                                         ...                     0
# 809                                         ...                     0
# 810                                         ...                     1
# 811                                         ...                     0
# 812                                         ...                     2
# 813                                         ...                     0
# 814                                         ...                     2
# 815                                         ...                     0
# 816                                         ...                     0
# 817                                         ...                     0
# 818                                         ...                     0
# 819                                         ...                     1
# 820       Brazil win on penalties (3 - 2)   ...                     0
# 821                                         ...                     0
# 822                                         ...                     0
# 823          Germany win after extra time   ...                     0
# 824                                         ...                     0
# 825                                         ...                     1
# 826                                         ...                     5
# 827                                         ...                     2
# 828          Germany win after extra time   ...                     0
# 829    Argentina win on penalties (2 - 4)   ...                     0
# 830  Netherlands win on penalties (4 - 3)   ...                     0
# 831                                         ...                     0
# 832                                         ...                     0
# 833   Costa Rica win on penalties (5 - 3)   ...                     0
# 834        Argentina win after extra time   ...                     0
# 835          Belgium win after extra time   ...                     0
# 836       Brazil win on penalties (3 - 2)   ...                     0
# 837                                         ...                     0
# 838                                         ...                     0
# 839   Costa Rica win on penalties (5 - 3)   ...                     0
# 840                                         ...                     0
# 841          Germany win after extra time   ...                     0
# 842        Argentina win after extra time   ...                     0
# 843          Belgium win after extra time   ...                     0
# 844                                         ...                     1
# 845                                         ...                     0
# 846                                         ...                     0
# 847  Netherlands win on penalties (4 - 3)   ...                     0
# 848                                         ...                     5
# 849    Argentina win on penalties (2 - 4)   ...                     0
# 850                                         ...                     2
# 851          Germany win after extra time   ...                     0
#
#                            Referee                     Assistant 1  \
# 802            ROLDAN Wilmar (COL)              DIAZ Eduardo (COL)
# 803            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 804          SHUKRALLA Nawaf (BHR)             TULEFAT Yaser (BHR)
# 805           Bakary GASSAMA (GAM)        MENKOUANDE Evarist (CMR)
# 806           ERIKSSON Jonas (SWE)         KLASENIUS Mathias (SWE)
# 807          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 808          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
# 809          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 810            PROENCA Pedro (POR)           MIRANDA Bertino (POR)
# 811              VERA Carlos (ECU)         LESCANO Christian (ECU)
# 812           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 813  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 814            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 815          Noumandiez DOUE (CIV)            YEO Songuifolo (CIV)
# 816          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 817          SHUKRALLA Nawaf (BHR)             TULEFAT Yaser (BHR)
# 818             Ben WILLIAMS (AUS)             CREAM Matthew (AUS)
# 819             C�neyt �AKIR (TUR)            DURAN Bahattin (TUR)
# 820              WEBB Howard (ENG)         MULLARKEY Michael (ENG)
# 821            Bj�rn KUIPERS (NED)         Sander VAN ROEKEL (NED)
# 822              GEIGER Mark (USA)                 HURD Sean (USA)
# 823             RICCI Sandro (BRA)       DE CARVALHO Emerson (BRA)
# 824  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 825            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 826          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
# 827          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 828           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 829             C�neyt �AKIR (TUR)            DURAN Bahattin (TUR)
# 830          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 831           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 832            PROENCA Pedro (POR)           MIRANDA Bertino (POR)
# 833             Ben WILLIAMS (AUS)             CREAM Matthew (AUS)
# 834           ERIKSSON Jonas (SWE)         KLASENIUS Mathias (SWE)
# 835          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 836              WEBB Howard (ENG)         MULLARKEY Michael (ENG)
# 837            Bj�rn KUIPERS (NED)         Sander VAN ROEKEL (NED)
# 838            PROENCA Pedro (POR)           MIRANDA Bertino (POR)
# 839             Ben WILLIAMS (AUS)             CREAM Matthew (AUS)
# 840              GEIGER Mark (USA)                 HURD Sean (USA)
# 841             RICCI Sandro (BRA)       DE CARVALHO Emerson (BRA)
# 842           ERIKSSON Jonas (SWE)         KLASENIUS Mathias (SWE)
# 843          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 844            PITANA Nestor (ARG)            MAIDANA Hernan (ARG)
# 845  Carlos VELASCO CARBALLO (ESP)  ALONSO FERNANDEZ Roberto (ESP)
# 846           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
# 847          Ravshan IRMATOV (UZB)     RASULOV Abduxamidullo (UZB)
# 848          RODRIGUEZ Marco (MEX)         TORRENTERA Marvin (MEX)
# 849             C�neyt �AKIR (TUR)            DURAN Bahattin (TUR)
# 850          HAIMOUDI Djamel (ALG)            ACHIK Redouane (MAR)
# 851           Nicola RIZZOLI (ITA)           Renato FAVERANI (ITA)
#
#                        Assistant 2 RoundID    MatchID  Home Team Initials  \
# 802        LESCANO Christian (ECU)  255931  300186495                 NSK
# 803       BELATTI Juan Pablo (ARG)  255931  300186483                 USA
# 804            SALEH Ebrahim (BHR)  255931  300186467                 AUS
# 805         KABANDA Felicien (RWA)  255931  300186470                 NED
# 806          WARNMARK Daniel (SWE)  255931  300186472                 CMR
# 807       KOCHKAROV Bakhadyr (KGZ)  255931  300186452                 CRO
# 808          QUINTERO Marcos (MEX)  255931  300186465                 ITA
# 809        ETCHIALI Abdelhak (ALG)  255931  300186484                 CRC
# 810               TRIGO Jose (POR)  255931  300186457                 JPN
# 811             ROMERO Byron (ECU)  255931  300186455                 GRE
# 812           Andrea STEFANI (ITA)  255931  300186458                 NGA
# 813               YUSTE Juan (ESP)  255931  300186464                 BIH
# 814       BELATTI Juan Pablo (ARG)  255931  300186482                 HON
# 815  BIRUMUSHAHU Jean Claude (BDI)  255931  300186515                 ECU
# 816       KOCHKAROV Bakhadyr (KGZ)  255931  300186469                 USA
# 817            SALEH Ebrahim (BHR)  255931  300186476                 POR
# 818               ANAZ Hakan (AUS)  255931  300186480                 NSK
# 819              ONGUN Tarik (TUR)  255931  300186506                 ALG
# 820              Darren CANN (ENG)  255951  300186487                 BRA
# 821           Erwin ZEINSTRA (NED)  255951  300186491                 COL
# 822             FLETCHER Joe (CAN)  255951  300186462                 FRA
# 823        VAN GASSE Marcelo (BRA)  255951  300186460                 GER
# 824               YUSTE Juan (ESP)  255953  300186461                 BRA
# 825       BELATTI Juan Pablo (ARG)  255953  300186485                 FRA
# 826          QUINTERO Marcos (MEX)  255955  300186474                 BRA
# 827        ETCHIALI Abdelhak (ALG)  255957  300186502                 BRA
# 828           Andrea STEFANI (ITA)  255959  300186501                 GER
# 829              ONGUN Tarik (TUR)  255955  300186490                 NED
# 830       KOCHKAROV Bakhadyr (KGZ)  255953  300186488                 NED
# 831           Andrea STEFANI (ITA)  255953  300186504                 ARG
# 832               TRIGO Jose (POR)  255951  300186508                 NED
# 833               ANAZ Hakan (AUS)  255951  300186459                 CRC
# 834          WARNMARK Daniel (SWE)  255951  300186503                 ARG
# 835        ETCHIALI Abdelhak (ALG)  255951  300186497                 BEL
# 836              Darren CANN (ENG)  255951  300186487                 BRA
# 837           Erwin ZEINSTRA (NED)  255951  300186491                 COL
# 838               TRIGO Jose (POR)  255951  300186508                 NED
# 839               ANAZ Hakan (AUS)  255951  300186459                 CRC
# 840             FLETCHER Joe (CAN)  255951  300186462                 FRA
# 841        VAN GASSE Marcelo (BRA)  255951  300186460                 GER
# 842          WARNMARK Daniel (SWE)  255951  300186503                 ARG
# 843        ETCHIALI Abdelhak (ALG)  255951  300186497                 BEL
# 844       BELATTI Juan Pablo (ARG)  255953  300186485                 FRA
# 845               YUSTE Juan (ESP)  255953  300186461                 BRA
# 846           Andrea STEFANI (ITA)  255953  300186504                 ARG
# 847       KOCHKAROV Bakhadyr (KGZ)  255953  300186488                 NED
# 848          QUINTERO Marcos (MEX)  255955  300186474                 BRA
# 849              ONGUN Tarik (TUR)  255955  300186490                 NED
# 850        ETCHIALI Abdelhak (ALG)  255957  300186502                 BRA
# 851           Andrea STEFANI (ITA)  255959  300186501                 GER
#
#      Away Team Initials Total Goals Half-time Goals
# 802                 ALG           6               3
# 803                 POR           4               1
# 804                 ESP           3               1
# 805                 CHI           2               0
# 806                 BRA           5               3
# 807                 MEX           4               0
# 808                 URU           1               0
# 809                 ENG           0               0
# 810                 COL           5               2
# 811                 CIV           3               1
# 812                 ARG           5               3
# 813                 IRN           4               1
# 814                 SUI           3               2
# 815                 FRA           0               0
# 816                 GER           1               0
# 817                 GHA           3               1
# 818                 BEL           1               0
# 819                 RUS           2               1
# 820                 CHI           2               0
# 821                 URU           2               1
# 822                 NGA           2               0
# 823                 ALG           3               0
# 824                 COL           3               1
# 825                 GER           1               1
# 826                 GER           8               5
# 827                 NED           3               2
# 828                 ARG           1               0
# 829                 ARG           0               0
# 830                 CRC           0               0
# 831                 BEL           1               1
# 832                 MEX           3               0
# 833                 GRE           2               0
# 834                 SUI           1               0
# 835                 USA           3               0
# 836                 CHI           2               0
# 837                 URU           2               1
# 838                 MEX           3               0
# 839                 GRE           2               0
# 840                 NGA           2               0
# 841                 ALG           3               0
# 842                 SUI           1               0
# 843                 USA           3               0
# 844                 GER           1               1
# 845                 COL           3               1
# 846                 BEL           1               1
# 847                 CRC           0               0
# 848                 GER           8               5
# 849                 ARG           0               0
# 850                 NED           3               2
# 851                 ARG           1               0
#
# [50 rows x 22 columns]

# %% [markdown]
# ## Summary
#
# In this lab, you practiced accessing data within Pandas!
